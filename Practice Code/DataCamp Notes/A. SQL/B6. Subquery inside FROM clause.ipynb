# %% [markdown]
# # SQL Cheat Sheet
# SUBQUERIES WITHIN FROM

# %% [markdown]
# - Connecting to Database

# %%
reload_ext sql

# %%
# %%sql
# postgresql://localhost/countries
# Out:
# 'Connected: @countries'

# %%
# %%sql
# SELECT * FROM languages
# LIMIT 2
# Out:
#  * postgresql://localhost/countries
#    postgresql://localhost/leaders
# 2 rows affected.
# [(1, 'AFG', 'Dari', 50.0, True), (2, 'AFG', 'Pashto', 35.0, True)]

# %%
# %%sql
# SELECT * FROM countries
# LIMIT 2
# Out:
#  * postgresql://localhost/countries
#    postgresql://localhost/leaders
# 2 rows affected.
# [('AFG', 'Afghanistan', 'Asia', 'Southern and Central Asia', 652090.0, 1919, 'Afganistan/Afqanestan', 'Islamic Emirate', 'Kabul', 69.1761, 34.5228),
#  ('NLD', 'Netherlands', 'Europe', 'Western Europe', 41526.0, 1581, 'Nederland', 'Constitutional Monarchy', 'Amsterdam', 4.89095, 52.3738)]

# %% [markdown]
# ___

# %% [markdown]
# ## 1. Subquery Inside FROM

# %% [markdown]
# - Determine the number of languagses spoken in each country in the countries table

# %%
# %%sql
# SELECT local_name, subquery.lang_count
# FROM countries,
#     (SELECT code, COUNT(name) AS lang_count FROM languages
#     GROUP BY code) AS subquery
# WHERE countries.code = subquery.code
# ORDER BY lang_count DESC
# Out:
#  * postgresql://localhost/countries
#    postgresql://localhost/leaders
# 199 rows affected.
# [('Zambia', 19),
#  ('YeItyop´iya', 16),
#  ('Zimbabwe', 16),
#  ('Bharat/India', 14),
#  ('Nepal', 14),
#  ('Mali', 13),
#  ('France', 13),
#  ('South Africa', 13),
#  ('Malawi', 12),
#  ('Angola', 12),
#  ('Pakistan', 11),
#  ('Panama', 11),
#  ('Ghana', 11),
#  ('Singapore/Singapura/Xinjiapo/Singapur', 10),
#  ('Kypros/Kibris', 10),
#  ('Canada', 10),
#  ('Schweiz/Suisse/Svizzera/Svizra', 10),
#  ('Belize', 9),
#  ('Australia', 9),
#  ('Zhongquo', 9),
#  ('Micronesia', 9),
#  ('Namibia', 9),
#  ('Botswana', 9),
#  ('New Zealand/Aotearoa', 9),
#  ('Mocambique', 8),
#  ('Sao Tome e Principe', 8),
#  ('Iran', 8),
#  ('Malaysia', 8),
#  ('Suriya', 7),
#  ('Aruba', 7),
#  ('Bolivia', 7),
#  ('Moldova', 7),
#  ('Magyarorszag', 7),
#  ('Al-Maghrib', 7),
#  ('Northern Mariana Islands', 7),
#  ('Senegal/Sounougal', 7),
#  ('Ertra', 7),
#  ('Nigeria', 6),
#  ('Uganda', 6),
#  ('Makedonija', 6),
# ...

# %% [markdown]
# ____

# %%
# %%sql
# postgresql://localhost/leaders
# Out:
# 'Connected: @leaders'

# %%
# %%sql
# SELECT * FROM states
# Out:
#    postgresql://localhost/countries
#  * postgresql://localhost/leaders
# 13 rows affected.
# [('Australia', 'Oceania', 1901, 1.88, 32.74),
#  ('Brunei', 'Asia', 1984, 1.96, 6.06),
#  ('Chile', 'South America', 1810, 1.8, 15.82),
#  ('Egypt', 'Africa', 1922, 2.7, 14.9),
#  ('Haiti', 'North America', 1804, 3.03, 2.74),
#  ('India', 'Asia', 1947, 2.43, 11.58),
#  ('Liberia', 'Africa', 1847, 4.64, 11.65),
#  ('Norway', 'Europe', 1905, 1.93, 39.6),
#  ('Oman', 'Asia', 1951, 2.75, 8.82),
#  ('Portugal', 'Europe', 1143, 1.31, 34.8),
#  ('Spain', 'Europe', 1492, 1.53, 38.64),
#  ('Uruguay', 'South America', 1828, 2.03, 22.31),
#  ('Vietnam', 'Asia', 1945, 1.7, 24.0)]

# %%
# %%sql
# SELECT * FROM monarchs
# Out:
#    postgresql://localhost/countries
#  * postgresql://localhost/leaders
# 4 rows affected.
# [('Brunei', 'Asia', 'Hassanal Bolkiah'),
#  ('Oman', 'Asia', 'Qaboos bin Said al Said'),
#  ('Norway', 'Europe', 'Harald V'),
#  ('Spain', 'Europe', 'Felipe VI')]

# %% [markdown]
# ___

# %% [markdown]
# - Max percentage of women in parliament  for each continent in the states table

# %%
# %%sql
# SELECT continent, MAX(women_parli_perc) AS max_perc
# FROM states
# GROUP BY continent
# ORDER BY continent
# Out:
#    postgresql://localhost/countries
#  * postgresql://localhost/leaders
# 6 rows affected.
# [('Africa', 14.9),
#  ('Asia', 24.0),
#  ('Europe', 39.6),
#  ('North America', 2.74),
#  ('Oceania', 32.74),
#  ('South America', 22.31)]

# %% [markdown]
# - Max percentage of women in parliament  for each continent in the monarchs table

# %%
# %%sql
# SELECT DISTINCT monarchs.continent, subquery.max_perc
# FROM monarchs,
#     (SELECT continent, MAX(women_parli_perc) AS max_perc
#     FROM states
#     GROUP BY continent) AS subquery
# WHERE monarchs.continent = subquery.continent
# ORDER BY continent;
# Out:
#    postgresql://localhost/countries
#  * postgresql://localhost/leaders
# 2 rows affected.
# [('Asia', 24.0), ('Europe', 39.6)]

# %% [markdown]
# ___
