# %% [markdown]
# # Matplotlib Cheat Sheet
# LINE PLOTS | CUSTOMIZATIONS | SCALES

# %% [markdown]
# ___

# %% [markdown]
# ## 1. Importing & Plotting Overview

# %% [markdown]
# - #### Importing

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# - #### Plotting Cmmands
#  - After plt.plot( ) command you need plt.show( ) command to display
#  - if plt.plot( ) has only one argument(e.g. a list), python will use the index of the list to map the x axis
#  - plt.clf( ) clear the previsouly shown figure

# %%
# plt.plot(x)
# plt.plot(x, y)
# plt.show()
# plt.clf()
# plt.xlabel()
# plt.ylabel()
# plt.title()
# plt.legend()

# %% [markdown]
# ___

# %% [markdown]
# ## 2. Line Plots

# %%
import pandas as pd

# %%
# Creating dictionaries holding workers weekly hours

deshaun = {'weekday': ['M', 'Tu', 'W', 'Th', 'F'], 'hours': [8,5,3,5,8] }
aditya = {'weekday': ['M', 'Tu', 'W', 'Th', 'F'], 'hours': [10,2,1,0,0] }
mengfei = {'weekday': ['M', 'Tu', 'W', 'Th', 'F'], 'hours': [0,0,5,9,5] }

# %%
# converting dictionaries to dataframes

deshaun_df = pd.DataFrame(deshaun)
aditya_df = pd.DataFrame(aditya)
mengfei_df = pd.DataFrame(mengfei)

display (deshaun_df)
# Out:
#   weekday  hours
# 0       M      8
# 1      Tu      5
# 2       W      3
# 3      Th      5
# 4       F      8

# %%
# defining axes

x = deshaun_df['weekday']
y = deshaun_df['hours']
x1 = aditya_df['weekday']
y1 = aditya_df['hours']
x2 = mengfei_df['weekday']
y2 = mengfei_df['hours']

# %%
plt.plot(x,y)
plt.plot(x1,y1)
plt.plot(x2,y2)
plt.show()

# %% [markdown]
# ___

# %% [markdown]
# ## 3. Plot customisations

# %% [markdown]
# - #### Adding Axis Labels and title

# %%
# LABELS AND TITLES
plt.xlabel('Weekday')
plt.ylabel('Hours Worked')
plt.title('Time Sheet')

plt.plot(x,y)
plt.plot(x1,y1)
plt.plot(x2,y2)
plt.show()

# %% [markdown]
# - #### Adding Legends
#  -  add label argument to plt.plot(x,y,label ='')
#  - you have to add plt.legend( ) just before plt.show() for it to work

# %%
plt.xlabel('Weekday')
plt.ylabel('Hours Worked')
plt.title('Time Sheet')

# ADD LEGENDS
plt.plot(x, y, label = 'Deshaun')
plt.plot(x1, y1, label = 'Aditya')
plt.plot(x2, y2, label = 'Mengfei')

# ADD LEGEND
plt.legend()
plt.show()

# %% [markdown]
# - #### Adding text
# plt.text(x-coord, y-coord, 'text here')

# %%
plt.xlabel('Weekday')
plt.ylabel('Hours Worked')
plt.title('Time Sheet')

plt.plot(x, y, label = 'Deshaun')
plt.plot(x1, y1, label = 'Aditya')
plt.plot(x2, y2, label = 'Mengfei')

# ADD TEXT
plt.text(3, 2, 'Testing text')
plt.legend()
plt.show()

# %% [markdown]
# - #### Font Size
#  - Add font size argument

# %%
plt.xlabel('Weekday')
plt.ylabel('Hours Worked')

# FONT SIZE
plt.title('Time Sheet', fontsize = 20)

plt.plot(x, y, label = 'Deshaun')
plt.plot(x1, y1, label = 'Aditya')
plt.plot(x2, y2, label = 'Mengfei')

# FONT SIZE
plt.text(3, 2, 'Testing text', fontsize = 14)
plt.legend()
plt.show()

# %% [markdown]
# - #### Line Width

# %%
plt.xlabel('Weekday')
plt.ylabel('Hours Worked')
plt.title('Time Sheet')

# CHANGE LINEWIDTH
plt.plot(x, y, label = 'Deshaun', linewidth = 4)
plt.plot(x1, y1, label = 'Aditya', linewidth = 4)
plt.plot(x2, y2, label = 'Mengfei', linewidth = 4)

plt.text(3, 2, 'Testing text')
plt.legend()
plt.show()

# %% [markdown]
# - #### Line Style

# %%
plt.xlabel('Weekday')
plt.ylabel('Hours Worked')
plt.title('Time Sheet')

# LINE STYLE # Straight line linestyle = '-'
plt.plot(x, y, label = 'Deshaun', linestyle = ':')
plt.plot(x1, y1, label = 'Aditya', linestyle = '--')
plt.plot(x2, y2, label = 'Mengfei', linestyle = '-.')

plt.text(3, 2, 'Testing text')
plt.legend()
plt.show()

# %% [markdown]
# - #### Markers

# %%
plt.xlabel('Weekday')
plt.ylabel('Hours Worked')
plt.title('Time Sheet')

# MARKERS # OTHERS d, *, h
plt.plot(x, y, label = 'Deshaun', marker = 'x')
plt.plot(x1, y1, label = 'Aditya', marker = 's')
plt.plot(x2, y2, label = 'Mengfei', marker = 'o')

plt.text(3, 2, 'Testing text')
plt.legend()

plt.show()

# %% [markdown]
# - #### Ticks
# - ticks are a list of markings for the axis

# %%
plt.xlabel('Weekday')
plt.ylabel('Hours Worked')
plt.title('Time Sheet')

plt.plot(x, y, label = 'Deshaun', marker = 'x')
plt.plot(x1, y1, label = 'Aditya', marker = 's')
plt.plot(x2, y2, label = 'Mengfei', marker = 'o')

plt.text(3, 2, 'Testing text')
plt.legend()

# ADD TICKS
plt.yticks([0, 5, 10])

plt.style.use('seaborn')
plt.show()

# %% [markdown]
# Add custom labels for ticks

# %%
plt.xlabel('Weekday')
plt.ylabel('Hours Worked')
plt.title('Time Sheet')

plt.plot(x, y, label = 'Deshaun', marker = 'x')
plt.plot(x1, y1, label = 'Aditya', marker = 's')
plt.plot(x2, y2, label = 'Mengfei', marker = 'o')

plt.text(3, 2, 'Testing text')
plt.legend()

# ADD TICKS
plt.yticks([0, 5, 10], ['Zero', 'Five', 'Ten'])

plt.style.use('seaborn')
plt.show()

# %% [markdown]
# ___

# %% [markdown]
# ## 4. Plot Styles
# - View all styles by print(plt.style.available)
# - Apply style with plt.style.use('ggplot')
# - Replace ggplot below with any other style to see what it looks like

# %%
print(plt.style.available)
# Out:
# ['seaborn-dark', 'seaborn-darkgrid', 'seaborn-ticks', 'fivethirtyeight', 'seaborn-whitegrid', 'classic', '_classic_test', 'fast', 'seaborn-talk', 'seaborn-dark-palette', 'seaborn-bright', 'seaborn-pastel', 'grayscale', 'seaborn-notebook', 'ggplot', 'seaborn-colorblind', 'seaborn-muted', 'seaborn', 'Solarize_Light2', 'seaborn-paper', 'bmh', 'tableau-colorblind10', 'seaborn-white', 'dark_background', 'seaborn-poster', 'seaborn-deep']

# %%
plt.xlabel('Weekday')
plt.ylabel('Hours Worked')
plt.title('Time Sheet')

# MARKERS # OTHERS d, *, h
plt.plot(x, y, label = 'Deshaun', marker = 'x')
plt.plot(x1, y1, label = 'Aditya', marker = 's')
plt.plot(x2, y2, label = 'Mengfei', marker = 'o')

# ADD TEXT
plt.text(3, 2, 'Testing text')
plt.legend()
plt.style.use('ggplot')
plt.show()

# %% [markdown]
# ___

# %% [markdown]
# ## 4. Scales

# %% [markdown]
# - #### Log Scale
#  - Puts the x-axis on a logarithmic scale

# %%
# plt.xscale('log')
